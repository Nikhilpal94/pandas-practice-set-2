# %%
import pandas as pd
df=pd.read_csv(r"C:\\Users\\nikhil pal\\Downloads\\ExportCSV (new).csv")
df
# Out:
#      ID                   Job Title                         Email Address  \
# 0     1       Laboratory Technician           Domenic_Bell5507@iatim.tech
# 1     2                 Electrician             Nick_Roman8659@mafthy.com
# 2     3                   Paramedic            Tyler_Lane8835@ubusive.com
# 3     4                  Bookkeeper  Johnathan_Wellington1704@bulaffy.com
# 4     5  Call Center Representative               John_Walker52@twace.org
# ..  ...                         ...                                   ...
# 95   96  Call Center Representative         Daphne_Drummond2548@liret.org
# 96   97                     Cashier          Anabelle_Adams3216@tonsy.org
# 97   98                   Webmaster              Bob_Kelly6609@mafthy.com
# 98   99            Mobile Developer        Barry_Robertson6887@nimogy.biz
# 99  100                       Clerk           Stella_West6413@bulaffy.com
#
#       FirstName LastName      Type of bussiness           address  people
# ...

# %% [markdown]
# # head parameter

# %%
n=df.head(11)
n
# Out:
#     ID                   Job Title                         Email Address  \
# 0    1       Laboratory Technician           Domenic_Bell5507@iatim.tech
# 1    2                 Electrician             Nick_Roman8659@mafthy.com
# 2    3                   Paramedic            Tyler_Lane8835@ubusive.com
# 3    4                  Bookkeeper  Johnathan_Wellington1704@bulaffy.com
# 4    5  Call Center Representative               John_Walker52@twace.org
# 5    6             Assistant Buyer            Caleb_Murphy3529@brety.org
# 6    7                     Steward            Maia_Russell5715@twace.org
# 7    8          Executive Director           Emely_Cameron9455@qater.org
# 8    9               HR Specialist             Liam_Camden140@ovock.tech
# 9   10              Budget Analyst              Luke_Ward9142@muall.tech
# 10  11                 Electrician              Alba_Nobbs4209@atink.com
#
#       FirstName LastName Type of bussiness        address  people
# ...

# %% [markdown]
# # tail parameter

# %%
p=df.tail(-20)
p
# Out:
#      ID                   Job Title                   Email Address  \
# 20   21                CNC Operator       Fred_Lewis8773@typill.biz
# 21   22          Executive Director   Cecilia_Townend6499@sheye.org
# 22   23          Production Painter       Marvin_King2791@liret.org
# 23   24                 Audiologist      Benny_Power8629@bauros.biz
# 24   25                 Stockbroker  Julian_Dickson9656@ubusive.com
# ..  ...                         ...                             ...
# 95   96  Call Center Representative   Daphne_Drummond2548@liret.org
# 96   97                     Cashier    Anabelle_Adams3216@tonsy.org
# 97   98                   Webmaster        Bob_Kelly6609@mafthy.com
# 98   99            Mobile Developer  Barry_Robertson6887@nimogy.biz
# 99  100                       Clerk     Stella_West6413@bulaffy.com
#
#    FirstName LastName      Type of bussiness           address  people
# 20         Fred Lewis           Global Print       Jersey City       2
# ...

# %%
h=df[['ID','people']]
h
# Out:
#      ID  people
# 0     1       3
# 1     2       7
# 2     3       0
# 3     4       2
# 4     5       5
# ..  ...     ...
# 95   96       6
# 96   97       6
# 97   98       5
# 98   99       4
# 99  100       2
#
# [100 rows x 2 columns]

# %% [markdown]
# # inculed head parameter

# %%
l=df[["ID","people"]].head(11)
l
# Out:
#     ID  people
# 0    1       3
# 1    2       7
# 2    3       0
# 3    4       2
# 4    5       5
# 5    6       1
# 6    7       4
# 7    8       1
# 8    9       6
# 9   10       8
# 10  11       2

# %% [markdown]
# # reupdated value

# %%
n=df[['ID','address','people']]
(n)
# Out:
#      ID           address  people
# 0     1         St. Louis       3
# 1     2     Moreno Valley       7
# 2     3        Louisville       0
# 3     4            Lisbon       2
# 4     5        Huntsville       5
# ..  ...               ...     ...
# 95   96          Amarillo       6
# 96   97             Otawa       6
# 97   98         Henderson       5
# 98   99            Irving       4
# 99  100  Colorado Springs       2
#
# [100 rows x 3 columns]

# %%
import pandas as pd
df1=pd.read_csv("C:\\Users\\nikhil pal\\Downloads\\ExportCSV (new).csv")
df1
# Out:
#      ID                   Job Title                         Email Address  \
# 0     1       Laboratory Technician           Domenic_Bell5507@iatim.tech
# 1     2                 Electrician             Nick_Roman8659@mafthy.com
# 2     3                   Paramedic            Tyler_Lane8835@ubusive.com
# 3     4                  Bookkeeper  Johnathan_Wellington1704@bulaffy.com
# 4     5  Call Center Representative               John_Walker52@twace.org
# ..  ...                         ...                                   ...
# 95   96  Call Center Representative         Daphne_Drummond2548@liret.org
# 96   97                     Cashier          Anabelle_Adams3216@tonsy.org
# 97   98                   Webmaster              Bob_Kelly6609@mafthy.com
# 98   99            Mobile Developer        Barry_Robertson6887@nimogy.biz
# 99  100                       Clerk           Stella_West6413@bulaffy.com
#
#       FirstName LastName      Type of bussiness           address  people
# ...

# %% [markdown]
# # describe parameter

# %%
n=df.describe(include="all")
n
# Out:
#                 ID     Job Title                Email Address  \
# count   100.000000           100                          100
# unique         NaN            47                          100
# top            NaN  Cash Manager  Domenic_Bell5507@iatim.tech
# freq           NaN             4                            1
# mean     50.500000           NaN                          NaN
# std      29.011492           NaN                          NaN
# min       1.000000           NaN                          NaN
# 25%      25.750000           NaN                          NaN
# 50%      50.500000           NaN                          NaN
# 75%      75.250000           NaN                          NaN
# max     100.000000           NaN                          NaN
#
#        FirstName LastName Type of bussiness      address      people
# count                 100               100          100  100.000000
# unique                100                29           64         NaN
# ...

# %% [markdown]
# # slicing how to import csv file and removing indexing

# %%
ndf=df.iloc[10:80,0:4]
ndf.to_csv(r"C:\Users\nikhil pal\Pictures\Saved Pictures\ndf2.csv",index=False)

# %%
import pandas as pd
df=pd.read_csv(r"C:\\Users\\nikhil pal\\Downloads\\ExportCSV (new).csv")
df2=df.loc[df['people']>5]
df2
# Out:
#     ID                   Job Title                      Email Address  \
# 1    2                 Electrician          Nick_Roman8659@mafthy.com
# 8    9               HR Specialist          Liam_Camden140@ovock.tech
# 9   10              Budget Analyst           Luke_Ward9142@muall.tech
# 13  14          Executive Director   Courtney_Egerton8395@cispeto.com
# 17  18       Healthcare Specialist      Clint_Reynolds7828@typill.biz
# 21  22          Executive Director      Cecilia_Townend6499@sheye.org
# 22  23          Production Painter          Marvin_King2791@liret.org
# 24  25                 Stockbroker     Julian_Dickson9656@ubusive.com
# 26  27                  Pharmacist     Chanelle_Connell6499@zorer.org
# 28  29                   Inspector         Margaret_Moore35@tonsy.org
# 34  35              Retail Trainee        Martin_Harper2806@liret.org
# 39  40                  Bookkeeper      Boris_Emerson8739@cispeto.com
# ...

# %%
df2=df.loc[df['people']>5]
df2
# Out:
#     ID                   Job Title                      Email Address  \
# 1    2                 Electrician          Nick_Roman8659@mafthy.com
# 8    9               HR Specialist          Liam_Camden140@ovock.tech
# 9   10              Budget Analyst           Luke_Ward9142@muall.tech
# 13  14          Executive Director   Courtney_Egerton8395@cispeto.com
# 17  18       Healthcare Specialist      Clint_Reynolds7828@typill.biz
# 21  22          Executive Director      Cecilia_Townend6499@sheye.org
# 22  23          Production Painter          Marvin_King2791@liret.org
# 24  25                 Stockbroker     Julian_Dickson9656@ubusive.com
# 26  27                  Pharmacist     Chanelle_Connell6499@zorer.org
# 28  29                   Inspector         Margaret_Moore35@tonsy.org
# 34  35              Retail Trainee        Martin_Harper2806@liret.org
# 39  40                  Bookkeeper      Boris_Emerson8739@cispeto.com
# ...

# %%
df3=df.loc[df['people']==5]
df3
# Out:
#     ID                   Job Title                  Email Address  \
# 4    5  Call Center Representative        John_Walker52@twace.org
# 19  20                        Cook    Denny_Leslie7147@kideod.biz
# 23  24                 Audiologist     Benny_Power8629@bauros.biz
# 32  33                   Biologist       Tyler_Allen387@twace.org
# 41  42          Executive Director         Ema_Dann1289@yahoo.com
# 67  68      Front Desk Coordinator  Cynthia_Larsen3489@ovock.tech
# 73  74             Design Engineer   Matthew_Judd1571@cispeto.com
# 74  75            Machine Operator  Aileen_Becker2775@womeona.net
# 91  92            Ambulatory Nurse   Barry_Ogilvy1365@ubusive.com
# 97  98                   Webmaster       Bob_Kelly6609@mafthy.com
#
#    FirstName LastName Type of bussiness      address  people
# 4         John Walker            Boeing   Huntsville       5
# 19       Denny Leslie           Comcast    Milwaukee       5
# ...

# %%
df4=df.loc[df['Job Title']=='Executive Director']
df4
# Out:
#     ID           Job Title                     Email Address  \
# 7    8  Executive Director       Emely_Cameron9455@qater.org
# 13  14  Executive Director  Courtney_Egerton8395@cispeto.com
# 21  22  Executive Director     Cecilia_Townend6499@sheye.org
# 41  42  Executive Director            Ema_Dann1289@yahoo.com
#
#    FirstName LastName Type of bussiness      address  people
# 7       Emely Cameron          Erickson  New Orleans       1
# 13   Courtney Egerton        Amazon.com    St. Louis       7
# 21    Cecilia Townend            Comodo       Boston       7
# 41           Ema Dann        Apple Inc.   Pittsburgh       5

# %%
df4=df.loc[(df['Job Title']=='Executive Director') | (df ['people']>5)]
df4
# Out:
#     ID                   Job Title                      Email Address  \
# 1    2                 Electrician          Nick_Roman8659@mafthy.com
# 7    8          Executive Director        Emely_Cameron9455@qater.org
# 8    9               HR Specialist          Liam_Camden140@ovock.tech
# 9   10              Budget Analyst           Luke_Ward9142@muall.tech
# 13  14          Executive Director   Courtney_Egerton8395@cispeto.com
# 17  18       Healthcare Specialist      Clint_Reynolds7828@typill.biz
# 21  22          Executive Director      Cecilia_Townend6499@sheye.org
# 22  23          Production Painter          Marvin_King2791@liret.org
# 24  25                 Stockbroker     Julian_Dickson9656@ubusive.com
# 26  27                  Pharmacist     Chanelle_Connell6499@zorer.org
# 28  29                   Inspector         Margaret_Moore35@tonsy.org
# 34  35              Retail Trainee        Martin_Harper2806@liret.org
# ...

# %%
df4=df.loc[((df['Job Title']=='Executive Director') & (df ['id']>20))] | (df['people']>5)]
# Out:
#   Input In [72]
#     df4=df.loc[((df['Job Title']=='Executive Director') & (df ['id']>20))] | (df['people']>5)]
#                                                                                              ^
# SyntaxError: unmatched ']'

# %% [markdown]
# # new data work

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA.csv")
df
# Out:
#       id first_name  last_name                      email  lucky no  \
# 0      1      Hulda     Deegan    hdeegan0@infoseek.co.jp        44
# 1      2      Cordi     Cuvley     ccuvley1@bloomberg.com        42
# 2      3    Georgie    Hammett       ghammett2@smh.com.au        20
# 3      4   Mohandas   Feldberg   mfeldberg3@delicious.com        30
# 4      5   Christie  Roubottom        croubottom4@ted.com        52
# ..   ...        ...        ...                        ...       ...
# 295  296     Hermon       Joan    hjoan87@photobucket.com        38
# 296  297      Karel     Wilcox  kwilcox88@stumbleupon.com        84
# 297  298     Markos  Simmonett       msimmonett89@mit.edu        40
# 298  299     Cammie     Elders    celders8a@newyorker.com        77
# 299  300      Flory       Taig           ftaig8b@ehow.com         2
#
#          car detils  Credit card detils  Gender  Married  Price
# 0           Corsica        2.018980e+14  Female     True  $9.41
# ...

# %%
c=df.describe(include='all')['Gender']
c
# Out:
# count      300
# unique       7
# top       Male
# freq       142
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
# Name: Gender, dtype: object

# %%
ndf=df.iloc[100:201,0:3]
ndf
# Out:
#       id first_name   last_name
# 100  101       Heda      Strang
# 101  102     Garrik      Marler
# 102  103        Tye  Le Strange
# 103  104         Ag  Grishmanov
# 104  105     Dennie      Garvie
# ..   ...        ...         ...
# 196  197   Margaret        Coom
# 197  198      Paige    Shirrell
# 198  199       Arvy      Chalke
# 199  200       Chan     Whawell
# 200  201    Mirelle    Newstead
#
# [101 rows x 3 columns]

# %%
ndf.to_csv(r"C:\Users\nikhil pal\Pictures\Saved Pictures\nikss.csv",index=False)

# %%
df2=df.loc[df["Married"]==True]
df2
# Out:
#       id first_name     last_name                          email  lucky no  \
# 0      1      Hulda        Deegan        hdeegan0@infoseek.co.jp        44
# 3      4   Mohandas      Feldberg       mfeldberg3@delicious.com        30
# 4      5   Christie     Roubottom            croubottom4@ted.com        52
# 5      6     Idette  Tewkesberrie  itewkesberrie5@shareasale.com        43
# 6      7       Debi        Carlow             dcarlow6@patch.com        50
# ..   ...        ...           ...                            ...       ...
# 290  291      Izaak      Instrell      iinstrell82@earthlink.net        63
# 291  292     Ailene      Cathrall    acathrall83@livejournal.com        25
# 292  293    Arleyne    Sommersett      asommersett84@spotify.com        84
# 295  296     Hermon          Joan        hjoan87@photobucket.com        38
# 297  298     Markos     Simmonett           msimmonett89@mit.edu        40
#
#          car detils  Credit card detils  Gender  Married  Price
# ...

# %%
df3=df2.loc[df2['Gender']=='Male']
df3
# Out:
#       id first_name  last_name                        email  lucky no  \
# 3      4   Mohandas   Feldberg     mfeldberg3@delicious.com        30
# 4      5   Christie  Roubottom          croubottom4@ted.com        52
# 7      8      Niall    Kilshaw   nkilshaw7@businesswire.com        17
# 11    12     Elliot     Eudall  eeudallb@simplemachines.org        57
# 12    13     Alleyn      Rojas              arojasc@free.fr         1
# ..   ...        ...        ...                          ...       ...
# 264  265    Herrick     Dryden      hdryden7c@bigcartel.com        42
# 282  283     Nikita   Mathewes        nmathewes7u@wikia.com        80
# 290  291      Izaak   Instrell    iinstrell82@earthlink.net        63
# 295  296     Hermon       Joan      hjoan87@photobucket.com        38
# 297  298     Markos  Simmonett         msimmonett89@mit.edu        40
#
#          car detils  Credit card detils Gender  Married  Price
# 3          Ram 2500        5.100140e+15   Male     True  $7.26
# ...

# %%
df4=df3.loc[df3['lucky no']>10]
df4
# Out:
#       id first_name  last_name                        email  lucky no  \
# 3      4   Mohandas   Feldberg     mfeldberg3@delicious.com        30
# 4      5   Christie  Roubottom          croubottom4@ted.com        52
# 7      8      Niall    Kilshaw   nkilshaw7@businesswire.com        17
# 11    12     Elliot     Eudall  eeudallb@simplemachines.org        57
# 13    14       Dino      Mingo        dmingod@hostgator.com        78
# ..   ...        ...        ...                          ...       ...
# 264  265    Herrick     Dryden      hdryden7c@bigcartel.com        42
# 282  283     Nikita   Mathewes        nmathewes7u@wikia.com        80
# 290  291      Izaak   Instrell    iinstrell82@earthlink.net        63
# 295  296     Hermon       Joan      hjoan87@photobucket.com        38
# 297  298     Markos  Simmonett         msimmonett89@mit.edu        40
#
#          car detils  Credit card detils Gender  Married  Price
# 3          Ram 2500        5.100140e+15   Male     True  $7.26
# ...

# %%
df5=df4.loc[df4['Married']==True]
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df5=df4.loc[df4['Married']==True]
#       2 df5
#
# NameError: name 'df4' is not defined

# %%
x1=df.loc[(df['Married']==True)&(df['Gender']=='Male')| (df['lucky no']>10)]
x1
# Out:
#       id  first_name  last_name                         email  lucky no  \
# 0      1       Hulda     Deegan       hdeegan0@infoseek.co.jp        44
# 1      2       Cordi     Cuvley        ccuvley1@bloomberg.com        42
# 2      3     Georgie    Hammett          ghammett2@smh.com.au        20
# 3      4    Mohandas   Feldberg      mfeldberg3@delicious.com        30
# 4      5    Christie  Roubottom           croubottom4@ted.com        52
# ..   ...         ...        ...                           ...       ...
# 293  294  Dianemarie  Parchment  dparchment85@yellowpages.com        24
# 295  296      Hermon       Joan       hjoan87@photobucket.com        38
# 296  297       Karel     Wilcox     kwilcox88@stumbleupon.com        84
# 297  298      Markos  Simmonett          msimmonett89@mit.edu        40
# 298  299      Cammie     Elders       celders8a@newyorker.com        77
#
#          car detils  Credit card detils  Gender  Married  Price
# ...

# %% [markdown]
# # pandas 2 ep 4

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA.csv")
df
# Out:
#       id first_name  last_name                      email  lucky no  \
# 0      1      Hulda     Deegan    hdeegan0@infoseek.co.jp        44
# 1      2      Cordi     Cuvley     ccuvley1@bloomberg.com        42
# 2      3    Georgie    Hammett       ghammett2@smh.com.au        20
# 3      4   Mohandas   Feldberg   mfeldberg3@delicious.com        30
# 4      5   Christie  Roubottom        croubottom4@ted.com        52
# ..   ...        ...        ...                        ...       ...
# 295  296     Hermon       Joan    hjoan87@photobucket.com        38
# 296  297      Karel     Wilcox  kwilcox88@stumbleupon.com        84
# 297  298     Markos  Simmonett       msimmonett89@mit.edu        40
# 298  299     Cammie     Elders    celders8a@newyorker.com        77
# 299  300      Flory       Taig           ftaig8b@ehow.com         2
#
#          car detils  Credit card detils  Gender  Married  Price
# 0           Corsica        2.018980e+14  Female     True  $9.41
# ...

# %% [markdown]
# # sort()

# %%
df1=df.sort_values('lucky no')
df1
# Out:
#       id first_name   last_name                          email  lucky no  \
# 12    13     Alleyn       Rojas                arojasc@free.fr         1
# 299  300      Flory        Taig               ftaig8b@ehow.com         2
# 144  145    Mildred     Waleran       mwaleran40@bloomberg.com         2
# 146  147   Horatius     Tunmore             htunmore42@cdc.gov         2
# 198  199       Arvy      Chalke            achalke5i@alexa.com         2
# ..   ...        ...         ...                            ...       ...
# 60    61      Taffy      Twohig          ttwohig1o@samsung.com        98
# 241  242  Hildagard      Upsale         hupsale6p@yolasite.com        98
# 102  103        Tye  Le Strange         tlestrange2u@exblog.jp        99
# 183  184     Boycey  Gansbuhler  bgansbuhler53@kickstarter.com       100
# 37    38     Jeanne      Gayden           jgayden11@sbwire.com       100
#
#       car detils  Credit card detils  Gender  Married  Price
# ...

# %%
df1=df.sort_values('lucky no',ascending=False)
df1
# Out:
#       id first_name   last_name                          email  lucky no  \
# 37    38     Jeanne      Gayden           jgayden11@sbwire.com       100
# 183  184     Boycey  Gansbuhler  bgansbuhler53@kickstarter.com       100
# 102  103        Tye  Le Strange         tlestrange2u@exblog.jp        99
# 14    15  Magdalene    Castagne               mcastagnee@51.la        98
# 60    61      Taffy      Twohig          ttwohig1o@samsung.com        98
# ..   ...        ...         ...                            ...       ...
# 146  147   Horatius     Tunmore             htunmore42@cdc.gov         2
# 238  239       Sean       Coare       scoare6m@theguardian.com         2
# 198  199       Arvy      Chalke            achalke5i@alexa.com         2
# 299  300      Flory        Taig               ftaig8b@ehow.com         2
# 12    13     Alleyn       Rojas                arojasc@free.fr         1
#
#          car detils  Credit card detils  Gender  Married  Price
# ...

# %% [markdown]
# # name,alphabatic behalf sorting()

# %%
df1=df.sort_values('Gender')
df1
# Out:
#       id first_name    last_name                         email  lucky no  \
# 49    50    Paolina     Van Ross  pvanross1d@timesonline.co.uk        12
# 54    55   Fiorenze     Meggison         fmeggison1i@amazon.de        23
# 184  185     Kellia  Errichiello        kerrichiello54@icio.us        63
# 61    62        Fee     Melluish    fmelluish1p@yellowbook.com        75
# 257  258   Florenza       Danell          fdanell75@utexas.edu        97
# ..   ...        ...          ...                           ...       ...
# 22    23     Rooney        Malec            rmalecm@utexas.edu        49
# 86    87      Amory    Witherdon       awitherdon2e@elpais.com         3
# 133  134     Wilona   Ballentime        wballentime3p@1688.com        71
# 214  215       Dode       Jallin             djallin5y@dot.gov        71
# 153  154      Irina       Eirwin    ieirwin49@domainmarket.com        26
#
#        car detils  Credit card detils      Gender  Married  Price
# ...

# %% [markdown]
# # multhi column sorting

# %%
df3=df.sort_values(['email','Gender','car detils'])
df
# Out:
#       id first_name   last_name                       email  lucky no  \
# 277  278     Andrei     Arnaldi    aarnaldi7p@parallels.com        24
# 126  127     Archer     Behrend         abehrend3i@bing.com        59
# 211  212    Antonie  Birtchnell  abirtchnell5v@vkontakte.ru        29
# 156  157   Angelico       Caney        acaney4c@typepad.com         6
# 46    47      Alika       Cantu      acantu1a@economist.com        73
# ..   ...        ...         ...                         ...       ...
# 191  192     Wesley      Duprey          wduprey5b@gmpg.org        61
# 9     10      Willa  Ivanchikov        wivanchikov9@wsj.com        16
# 228  229     Wynnie      Maleby    wmaleby6c@washington.edu         4
# 237  238    Waverly      Mellon        wmellon6l@usnews.com        78
# 32    33     Weidar       Spick           wspickw@ifeng.com        34
#
#           car detils  Credit card detils       Gender  Married  Price
# ...

# %%
df3.to_csv(r'C:\Users\nikhil pal\Pictures\Saved Pictures\nik.csv')

# %%
df4=df.sort_values(['email','last_name','Gender','lucky no'],ascending=[True,False,True,False])
df4
# Out:
#       id first_name   last_name                       email  lucky no  \
# 277  278     Andrei     Arnaldi    aarnaldi7p@parallels.com        24
# 126  127     Archer     Behrend         abehrend3i@bing.com        59
# 211  212    Antonie  Birtchnell  abirtchnell5v@vkontakte.ru        29
# 156  157   Angelico       Caney        acaney4c@typepad.com         6
# 46    47      Alika       Cantu      acantu1a@economist.com        73
# ..   ...        ...         ...                         ...       ...
# 191  192     Wesley      Duprey          wduprey5b@gmpg.org        61
# 9     10      Willa  Ivanchikov        wivanchikov9@wsj.com        16
# 228  229     Wynnie      Maleby    wmaleby6c@washington.edu         4
# 237  238    Waverly      Mellon        wmellon6l@usnews.com        78
# 32    33     Weidar       Spick           wspickw@ifeng.com        34
#
#           car detils  Credit card detils       Gender  Married  Price
# ...

# %%
df4.to_csv(r'C:\Users\nikhil pal\Pictures\Saved Pictures\nik2.csv')

# %% [markdown]
# # arange index column

# %%
df=df4.reset_index(drop=True)
df
# Out:
#       id first_name   last_name                       email  lucky no  \
# 0    278     Andrei     Arnaldi    aarnaldi7p@parallels.com        24
# 1    127     Archer     Behrend         abehrend3i@bing.com        59
# 2    212    Antonie  Birtchnell  abirtchnell5v@vkontakte.ru        29
# 3    157   Angelico       Caney        acaney4c@typepad.com         6
# 4     47      Alika       Cantu      acantu1a@economist.com        73
# ..   ...        ...         ...                         ...       ...
# 295  192     Wesley      Duprey          wduprey5b@gmpg.org        61
# 296   10      Willa  Ivanchikov        wivanchikov9@wsj.com        16
# 297  229     Wynnie      Maleby    wmaleby6c@washington.edu         4
# 298  238    Waverly      Mellon        wmellon6l@usnews.com        78
# 299   33     Weidar       Spick           wspickw@ifeng.com        34
#
#           car detils  Credit card detils       Gender  Married  Price
# ...

# %%
df=df4.reset_index()
df
# Out:
#      index   id first_name   last_name                       email  lucky no  \
# 0      277  278     Andrei     Arnaldi    aarnaldi7p@parallels.com        24
# 1      126  127     Archer     Behrend         abehrend3i@bing.com        59
# 2      211  212    Antonie  Birtchnell  abirtchnell5v@vkontakte.ru        29
# 3      156  157   Angelico       Caney        acaney4c@typepad.com         6
# 4       46   47      Alika       Cantu      acantu1a@economist.com        73
# ..     ...  ...        ...         ...                         ...       ...
# 295    191  192     Wesley      Duprey          wduprey5b@gmpg.org        61
# 296      9   10      Willa  Ivanchikov        wivanchikov9@wsj.com        16
# 297    228  229     Wynnie      Maleby    wmaleby6c@washington.edu         4
# 298    237  238    Waverly      Mellon        wmellon6l@usnews.com        78
# 299     32   33     Weidar       Spick           wspickw@ifeng.com        34
#
# ...

# %% [markdown]
# # add to two column

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (1).csv")
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\new data1.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
a=print(df[['Age','Education']])
a
print()
print()
b=print(df.info([['Age']]))
b
# Out:
#       Age  Education
# 0      41          2
# 1      49          1
# 2      37          2
# 3      33          4
# 4      27          1
# ...   ...        ...
# 1465   36          2
# 1466   39          1
# 1467   27          3
# 1468   49          3
# 1469   34          3
#
# [1470 rows x 2 columns]
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
# ...

# %%
a=df.describe(include="all")
a
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
a=df.describe(include="all")[['Age','Education']]
a
# Out:
#                 Age    Education
# count   1470.000000  1470.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      36.923810     2.912925
# std        9.135373     1.024165
# min       18.000000     1.000000
# 25%       30.000000     2.000000
# 50%       36.000000     3.000000
# 75%       43.000000     4.000000
# max       60.000000     5.000000

# %% [markdown]
# ep5

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (1).csv")
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
print(df.id)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: id, Length: 500, dtype: int64

# %%
print(df.columns)
print()
print()
print(df.dtypes)
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'City_name',
#        'Married', 'Car_colour', 'Car_model_year', 'Luncing_country'],
#       dtype='object')
#
#
# id                  int64
# first_name         object
# last_name          object
# email              object
# gender             object
# City_name          object
# Married              bool
# Car_colour         object
# Car_model_year      int64
# Luncing_country    object
# dtype: object

# %%
a=df.describe(include="all")[['first_name','Car_model_year','email','Married']]
a
# Out:
#        first_name  Car_model_year                      email Married
# count         500      500.000000                        500     500
# unique        482             NaN                        500       2
# top        Gloria             NaN  sclarae0@wunderground.com    True
# freq            3             NaN                          1     273
# mean          NaN     2000.810000                        NaN     NaN
# std           NaN        8.454161                        NaN     NaN
# min           NaN     1963.000000                        NaN     NaN
# 25%           NaN     1995.000000                        NaN     NaN
# 50%           NaN     2002.000000                        NaN     NaN
# 75%           NaN     2008.000000                        NaN     NaN
# max           NaN     2013.000000                        NaN     NaN

# %%
a=df.describe()
a
# Out:
#                id  Car_model_year
# count  500.000000      500.000000
# mean   250.500000     2000.810000
# std    144.481833        8.454161
# min      1.000000     1963.000000
# 25%    125.750000     1995.000000
# 50%    250.500000     2002.000000
# 75%    375.250000     2008.000000
# max    500.000000     2013.000000

# %%
c=df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               500 non-null    int64
#  1   first_name       500 non-null    object
#  2   last_name        500 non-null    object
#  3   email            500 non-null    object
#  4   gender           500 non-null    object
#  5   City_name        500 non-null    object
#  6   Married          500 non-null    bool
#  7   Car_colour       500 non-null    object
#  8   Car_model_year   500 non-null    int64
#  9   Luncing_country  500 non-null    object
# dtypes: bool(1), int64(2), object(7)
# memory usage: 35.8+ KB

# %%
ndf=df.iloc[100:201,0:9]
ndf
# Out:
#       id first_name last_name                        email      gender  \
# 100  101    Brenden    Gayler    bstillman2s@blinklist.com  Polygender
# 101  102       Devy    Gayler     delmore2t@eventbrite.com        Male
# 102  103       Chev    Gayler     cfrostdicke2u@oracle.com        Male
# 103  104    Walther    Gayler        wlighton2v@netlog.com        Male
# 104  105     Calvin    Gayler  cbilborough2w@artisteer.com        Male
# ..   ...        ...       ...                          ...         ...
# 196  197       Lida    Gayler         lthowes5g@github.com     Agender
# 197  198     Tillie    Gayler          tmelonby5h@furl.net      Female
# 198  199   Virgilio    Gayler      vnozzolii5i@spotify.com        Male
# 199  200        Lek    Gayler      losherin5j@multiply.com        Male
# 200  201        Gal    Gayler        gegar5k@bigcartel.com        Male
#
#              City_name  Married  Car_colour  Car_model_year
# ...

# %%
ndf.to_csv(r"C:\Users\nikhil pal\Pictures\Saved Pictures\all import file\new data1.csv",index=False)

# %%
df1=df.loc[df['Car_model_year']>2000]
df1
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# 6      7   Fernande    Gayler            fbeere6@hud.gov  Female
# ..   ...        ...       ...                        ...     ...
# 494  495      Cliff    Gayler   ctwelvetreedq@unicef.org    Male
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
df2=df1.loc[df1['Car_model_year']>2010]
df2
# Out:
#       id first_name last_name                               email  \
# 6      7   Fernande    Gayler                     fbeere6@hud.gov
# 30    31      Yance    Gayler               yhuglandu@booking.com
# 31    32     Jacobo    Gayler            jducastelv@123-reg.co.uk
# 35    36        Sal    Gayler                  srajchertz@cdc.gov
# 54    55      Fleur    Gayler           fdowsing1i@friendfeed.com
# 58    59      Tobit    Gayler      tpumfrey1m@theglobeandmail.com
# 60    61      Lucky    Gayler             lwilmott1o@bandcamp.com
# 63    64  Granville    Gayler           gcars1r@independent.co.uk
# 67    68      Ruthy    Gayler             rkillner1v@buzzfeed.com
# 79    80   Garnette    Gayler              gkingscote27@salon.com
# 91    92       Tina    Gayler                 twadforth2j@php.net
# 100  101    Brenden    Gayler           bstillman2s@blinklist.com
# 108  109     Orsola    Gayler                omcgilben30@webs.com
# ...

# %%
df3=df2.loc[df2['Car_model_year']>2010]
df3
# Out:
#       id first_name last_name                               email  \
# 6      7   Fernande    Gayler                     fbeere6@hud.gov
# 30    31      Yance    Gayler               yhuglandu@booking.com
# 31    32     Jacobo    Gayler            jducastelv@123-reg.co.uk
# 35    36        Sal    Gayler                  srajchertz@cdc.gov
# 54    55      Fleur    Gayler           fdowsing1i@friendfeed.com
# 58    59      Tobit    Gayler      tpumfrey1m@theglobeandmail.com
# 60    61      Lucky    Gayler             lwilmott1o@bandcamp.com
# 63    64  Granville    Gayler           gcars1r@independent.co.uk
# 67    68      Ruthy    Gayler             rkillner1v@buzzfeed.com
# 79    80   Garnette    Gayler              gkingscote27@salon.com
# 91    92       Tina    Gayler                 twadforth2j@php.net
# 100  101    Brenden    Gayler           bstillman2s@blinklist.com
# 108  109     Orsola    Gayler                omcgilben30@webs.com
# ...

# %%
df4=df3.loc[(df3['gender']=='Male') & (df3['Car_model_year']<2015) & (df3['Luncing_country']=='China')]
df4
# Out:
#       id first_name last_name                           email gender  \
# 58    59      Tobit    Gayler  tpumfrey1m@theglobeandmail.com   Male
# 254  255     Weston    Gayler             wmccheyne72@cdc.gov   Male
# 266  267     Giraud    Gayler         guglow7e@techcrunch.com   Male
# 305  306     Borden    Gayler       blowin8h@chronoengine.com   Male
# 496  497   Leonidas    Gayler              lmaddernds@ted.com   Male
#
#     City_name  Married Car_colour  Car_model_year Luncing_country
# 58   Liucheng     True     Fuscia            2011           China
# 254   Wukeshu    False     Yellow            2011           China
# 266    Jinhua    False    Crimson            2012           China
# 305   Chashan    False    Crimson            2011           China
# 496     Chiba    False      Green            2011           China

# %%
df=df.sort_values('Car_model_year',ascending=False)
df
# Out:
#       id first_name last_name                         email       gender  \
# 471  472    Westley    Gayler            wmcsarryd3@loc.gov         Male
# 146  147     Trevar    Gayler       tabbado42@rakuten.co.jp         Male
# 297  298     Ursola    Gayler           uinwood89@ifeng.com       Female
# 160  161       Kata    Gayler        kmaccardle4g@fotki.com       Female
# 31    32     Jacobo    Gayler      jducastelv@123-reg.co.uk         Male
# ..   ...        ...       ...                           ...          ...
# 368  369    Winonah    Gayler           wducea8@webnode.com       Female
# 257  258     Karine    Gayler     kallatt75@liveinternet.ru       Female
# 95    96    Lauritz    Gayler             lshone2n@etsy.com         Male
# 449  450     Bondie    Gayler  btommasuzzich@prnewswire.com   Polygender
# 46    47    Gothart    Gayler        gelcy1a@washington.edu  Genderfluid
#
#                   City_name  Married  Car_colour  Car_model_year  \
# ...

# %%
df2=df.sort_values(['id','Car_model_year'])
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df2=df.sort_values(['id','Car_model_year'])
#       2 df2
#
# NameError: name 'df' is not defined

# %%
df1=df.sort_values(['id','Car_model_year','Luncing_country'],ascending=[True,False,False])
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df1=df.sort_values(['id','Car_model_year','Luncing_country'],ascending=[True,False,False])
#       2 df1
#
# NameError: name 'df' is not defined

# %%
df.to_csv(r"C:\Users\nikhil pal\Pictures\Saved Pictures\all import file\mydata.csv")

# %%
df5=df.reset_index(drop=True)
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df5=df.reset_index(drop=True)
#       2 df5
#
# NameError: name 'df' is not defined

# %%
df['love']=df['id']+df['Car_model_year']
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country  \
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
df['tripal']=df['id']*3
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country  \
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
df['love']=df.iloc[:,4:11].sum(axis=1)
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_15196\3858238303.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['love']=df.iloc[:,4:11].sum(axis=1)
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# ...

# %%
df=df.drop(column=['love','tripal'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df=df.drop(column=['love','tripal'])
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: drop() got an unexpected keyword argument 'column'

# %%
l=e[0:2] + [e[-1]]+e[2:-1]
df=df[l]
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 l=e[0:2] + [e[-1]]+e[2:-1]
#       2 df=df[l]
#       3 print(df)
#
# NameError: name 'e' is not defined

# %%
inport pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df=df.sort_values("total",ascending=False)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.head(10)
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country  \
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %% [markdown]
# remove colume

# %%
df1=df.drop(columns=['tripal','love'])
df1
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
df['temp']=(df['id']*5-2)+(1/2)
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country  \
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %% [markdown]
# # concunate of two column

# %%
df['temp1']=df["first_name"]+ " "+df["last_name"]
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country  \
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
p=["love","tripal","temp","temp1"]

# %%
df=df.drop(columns=p)
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %% [markdown]
# # ep6-group by,filitering with loc

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (1).csv")
df
# Out:
#       id first_name last_name                      email  gender  \
# 0      1  Sherlocke    Clarae  sclarae0@wunderground.com    Male
# 1      2   Nathalia   Verryan      nverryan1@answers.com  Female
# 2      3  Alexander    Gayler    agayler2@shareasale.com    Male
# 3      4     Payton    Gayler    pstokoe3@techcrunch.com    Male
# 4      5   Sapphira    Gayler    sspaxman4@shinystat.com  Female
# ..   ...        ...       ...                        ...     ...
# 495  496    Freeman    Gayler      fdaybelldr@tripod.com    Male
# 496  497   Leonidas    Gayler         lmaddernds@ted.com    Male
# 497  498     Charis    Gayler     cjosedt@wikispaces.com  Female
# 498  499      Renee    Gayler   rwannelldu@discovery.com  Female
# 499  500    Candide    Gayler          crhysdv@ifeng.com  Female
#
#              City_name  Married Car_colour  Car_model_year Luncing_country
# 0           Alapayevsk     True  Turquoise            2007          Russia
# ...

# %%
ef=df.groupby("Married").count()
ef
# Out:
#           id  first_name  last_name  email  gender  City_name  Car_colour  \
# Married
# False    227         227        227    227     227        227         227
# True     273         273        273    273     273        273         273
#
#          Car_model_year  Luncing_country
# Married
# False               227              227
# True                273              273

# %%
gf=df.groupby("gender")["Married"].count()
gf
# Out:
# gender
# Agender          6
# Bigender         8
# Female         229
# Genderfluid     14
# Genderqueer      7
# Male           214
# Non-binary      13
# Polygender       9
# Name: Married, dtype: int64

# %%
ef1=df.groupby("Married").sum()
ef1
# Out:
#             id  Car_model_year
# Married
# False    59242          454120
# True     66008          546285

# %%
gf1=df.groupby('id')['Car_model_year'].mean()
gf1
# Out:
# id
# 1      2007.0
# 2      1986.0
# 3      2002.0
# 4      2006.0
# 5      2010.0
#         ...
# 496    2005.0
# 497    2011.0
# 498    1999.0
# 499    2012.0
# 500    2008.0
# Name: Car_model_year, Length: 500, dtype: float64

# %%
a=df['Car_model_year'].mean()
a
# Out:
# 2000.81

# %%
b=df.groupby(['first_name','gender'])['Married'].mean()
b
# Out:
# first_name  gender
# Ab          Male      1.0
# Abba        Male      0.0
# Adelbert    Male      1.0
# Adolphe     Male      0.0
# Adora       Female    0.0
#                      ...
# Yettie      Female    1.0
# Yorgo       Male      1.0
# Yorker      Male      1.0
# Yul         Male      0.0
# Zuzana      Female    1.0
# Name: Married, Length: 486, dtype: float64

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\ExportCSV (7).csv")
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
pd=df.groupby("FirstName LastName")['marks'].max()
print (pd)
# Out:
# FirstName LastName
# Abbey Payne         3
# Abbey Sloan         4
# Abdul Nobbs         2
# Abdul Watson        1
# Ada Baker           3
#                    ..
# Victoria Bingham    7
# Vivian King         3
# Wade Quinton        4
# William Ebden       5
# William Vollans     4
# Name: marks, Length: 250, dtype: int64

# %%
pd1=df.groupby("FirstName LastName")['speed'].min()
print (pd1)
# Out:
# FirstName LastName
# Abbey Payne         3
# Abbey Sloan         7
# Abdul Nobbs         0
# Abdul Watson        1
# Ada Baker           2
#                    ..
# Victoria Bingham    5
# Vivian King         2
# Wade Quinton        7
# William Ebden       2
# William Vollans     0
# Name: speed, Length: 250, dtype: int64

# %%
df.loc[df["speed"]>5,'spped']="fast"

# %%
a=df['speed'].mean()
a
# Out:
# 3.904

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2               fast     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247               fast           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName marks  speed  stength  Gender spped
# 0          Nathan Farmer     0      4        7    Male   NaN
# 1      Marigold Woodcock     2      6        0  Female  fast
# ...

# %%
pd=df.drop(columns='spped')
pd
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender     new
# 0          Nathan Farmer      0      4        7    Male    slow
# 1      Marigold Woodcock      2      6        0  Female  medium
# ...

# %%
import pandas as pd
df['new']="slow"
df.loc[(df['speed']>5)& (df["speed"]<10),"new"]="medium"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender spped     new
# 0          Nathan Farmer      0      4        7    Male   NaN    slow
# ...

# %%
df=df.drop(columns='spped')
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender     new
# 0          Nathan Farmer      0      4        7    Male    slow
# 1      Marigold Woodcock      2      6        0  Female  medium
# ...

# %%
df.loc[df['speed']<5,'Gendar']='slow'
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender Gendar
# 0          Nathan Farmer      0      4        7    Male   slow
# 1      Marigold Woodcock      2      6        0  Female   slow
# ...

# %% [markdown]
# # pandas joining ep 7

# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\nikhil pal\Desktop\python jupiter\myfile notpad..txt1.txt")
df2=pd.read_csv(r"C:\Users\nikhil pal\Desktop\python jupiter\myfile notpad..txt2.txt")
(df1)
(df2)
# Out:
#     id     yx     salaery
# 0    1      4                                4000
# 1    2      5                                3000
# 2    3      6                                5000
# 3    4      2                                1000
# 4    7      5                                7000
# 5    8      3                                2500

# %%
df=pd.concat([df1,df2])
df
# Out:
#     id     Name    \
# 0  1.0        joy
# 1  2.0      nihal
# 2  3.0       abhi
# 3  4.0   aditiya
# 4  5.0        raj
# 5  6.0      diesh
# 0  NaN        NaN
# 1  NaN        NaN
# 2  NaN        NaN
# 3  NaN        NaN
# 4  NaN        NaN
# 5  NaN        NaN
#
#    age                                                                    id  \
# 0                                               34.0                     NaN
# 1                                               43.0                     NaN
# 2                                               43.0                     NaN
# 3                                               67.0                     NaN
# 4                                               34.0                     NaN
# 5                                               34.0                     NaN
# 0                                                NaN                     1.0
# 1                                                NaN                     2.0
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#      id     Name    \
# 0   1.0        joy
# 1   2.0      nihal
# 2   3.0       abhi
# 3   4.0   aditiya
# 4   5.0        raj
# 5   6.0      diesh
# 6   NaN        NaN
# 7   NaN        NaN
# 8   NaN        NaN
# 9   NaN        NaN
# 10  NaN        NaN
# 11  NaN        NaN
#
#     age                                                                    id  \
# 0                                                34.0                     NaN
# 1                                                43.0                     NaN
# 2                                                43.0                     NaN
# 3                                                67.0                     NaN
# 4                                                34.0                     NaN
# 5                                                34.0                     NaN
# 6                                                 NaN                     1.0
# 7                                                 NaN                     2.0
# ...
